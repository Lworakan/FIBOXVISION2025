# %%
import pandas as pd

df = pd.read_csv('../Callback/merged_output.csv')
df
# Out:
#                         timestamp    x    y  depth  gyro_data.x  gyro_data.y  \
# 0      2025-03-05 02:04:57.925922  270  190  9.362       0.0005      -0.0027
# 1      2025-03-05 02:05:02.094286  282  218  8.743       0.0000      -0.0091
# 2      2025-03-05 02:05:04.661139  289  295  9.746      -0.0011      -0.0112
# 3      2025-03-05 02:05:05.795730  191  292  8.743      -0.0027      -0.0016
# 4      2025-03-05 02:05:06.562522  184  277  9.217      -0.0016      -0.0091
# ...                           ...  ...  ...    ...          ...          ...
# 22155  2025-03-05 02:56:11.341329  320  240  3.121       0.0021      -0.0101
# 22156  2025-03-05 02:56:11.375375  320  240  3.080      -0.0005      -0.0075
# 22157  2025-03-05 02:56:11.440879  320  240  3.162      -0.0016      -0.0053
# 22158  2025-03-05 02:56:11.675668  320  240  3.041       0.0027      -0.0101
# 22159  2025-03-05 02:56:11.708661  320  240  3.025       0.0005      -0.0080
#
#        gyro_data.z  accel_data.x  accel_data.y  accel_data.z  ground_truth
# 0           0.0032        0.2844       -9.1496       -0.0098           8.0
# 1           0.0000        0.2844       -9.1692        0.0000           8.0
# 2           0.0032        0.2844       -9.1496       -0.0294           8.0
# 3           0.0005        0.2844       -9.1496       -0.0098           8.0
# 4           0.0043        0.2844       -9.1496       -0.0294           8.0
# ...            ...           ...           ...           ...           ...
# 22155       0.0059        0.3628       -9.0515       -0.0294           3.0
# 22156      -0.0005        0.3628       -9.0515       -0.0098           3.0
# 22157       0.0016        0.3432       -9.0515       -0.0294           3.0
# 22158       0.0043        0.3432       -9.0515       -0.0294           3.0
# 22159      -0.0005        0.3628       -9.0712       -0.0490           3.0
#
# [22160 rows x 11 columns]

# %%
# new dataframe get only depth and accealdatax and ground_truth
data = df[['depth', 'ground_truth']]
data
# Out:
#        depth  ground_truth
# 0      9.362           8.0
# 1      8.743           8.0
# 2      9.746           8.0
# 3      8.743           8.0
# 4      9.217           8.0
# ...      ...           ...
# 22155  3.121           3.0
# 22156  3.080           3.0
# 22157  3.162           3.0
# 22158  3.041           3.0
# 22159  3.025           3.0
#
# [22160 rows x 2 columns]

# %%
from pycaret.regression import *
s = setup(data, target = 'ground_truth', session_id = 123, use_gpu=True, polynomial_features=True,polynomial_degree=2)
# Out:
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# <style type="text/css">
# #T_e62df_row8_col1, #T_e62df_row12_col1, #T_e62df_row17_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e62df">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e62df_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e62df_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e62df_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e62df_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e62df_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_e62df_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e62df_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e62df_row1_col1" class="data row1 col1" >ground_truth</td>
#     </tr>
#     <tr>
#       <th id="T_e62df_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e62df_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_e62df_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_e62df_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e62df_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_e62df_row3_col1" class="data row3 col1" >(22160, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_e62df_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e62df_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_e62df_row4_col1" class="data row4 col1" >(22160, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_e62df_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e62df_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_e62df_row5_col1" class="data row5 col1" >(15511, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_e62df_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e62df_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_e62df_row6_col1" class="data row6 col1" >(6649, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_e62df_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e62df_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_e62df_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e62df_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e62df_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_e62df_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e62df_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e62df_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_e62df_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e62df_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e62df_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_e62df_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e62df_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e62df_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_e62df_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_e62df_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e62df_row12_col0" class="data row12 col0" >Polynomial features</td>
#       <td id="T_e62df_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e62df_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e62df_row13_col0" class="data row13 col0" >Polynomial degree</td>
#       <td id="T_e62df_row13_col1" class="data row13 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e62df_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e62df_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_e62df_row14_col1" class="data row14 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_e62df_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e62df_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_e62df_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e62df_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e62df_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_e62df_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e62df_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e62df_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_e62df_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e62df_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e62df_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_e62df_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e62df_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e62df_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_e62df_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e62df_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_e62df_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_e62df_row20_col1" class="data row20 col1" >feda</td>
#     </tr>
#   </tbody>
# </table>
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_e188d th {
#   text-align: left;
# }
# #T_e188d_row0_col0, #T_e188d_row1_col0, #T_e188d_row1_col1, #T_e188d_row1_col2, #T_e188d_row1_col3, #T_e188d_row1_col4, #T_e188d_row1_col5, #T_e188d_row1_col6, #T_e188d_row2_col0, #T_e188d_row2_col1, #T_e188d_row2_col2, #T_e188d_row2_col3, #T_e188d_row2_col4, #T_e188d_row2_col5, #T_e188d_row3_col0, #T_e188d_row3_col1, #T_e188d_row3_col2, #T_e188d_row3_col3, #T_e188d_row3_col4, #T_e188d_row3_col5, #T_e188d_row4_col0, #T_e188d_row4_col1, #T_e188d_row4_col2, #T_e188d_row4_col3, #T_e188d_row4_col4, #T_e188d_row4_col5, #T_e188d_row4_col6, #T_e188d_row5_col0, #T_e188d_row5_col1, #T_e188d_row5_col2, #T_e188d_row5_col3, #T_e188d_row5_col4, #T_e188d_row5_col5, #T_e188d_row5_col6, #T_e188d_row6_col0, #T_e188d_row6_col1, #T_e188d_row6_col2, #T_e188d_row6_col3, #T_e188d_row6_col4, #T_e188d_row6_col5, #T_e188d_row6_col6, #T_e188d_row7_col0, #T_e188d_row7_col1, #T_e188d_row7_col2, #T_e188d_row7_col3, #T_e188d_row7_col4, #T_e188d_row7_col5, #T_e188d_row7_col6, #T_e188d_row8_col0, #T_e188d_row8_col1, #T_e188d_row8_col2, #T_e188d_row8_col3, #T_e188d_row8_col4, #T_e188d_row8_col5, #T_e188d_row8_col6, #T_e188d_row9_col0, #T_e188d_row9_col1, #T_e188d_row9_col2, #T_e188d_row9_col3, #T_e188d_row9_col4, #T_e188d_row9_col5, #T_e188d_row9_col6, #T_e188d_row10_col0, #T_e188d_row10_col1, #T_e188d_row10_col2, #T_e188d_row10_col3, #T_e188d_row10_col4, #T_e188d_row10_col5, #T_e188d_row10_col6, #T_e188d_row11_col0, #T_e188d_row11_col1, #T_e188d_row11_col2, #T_e188d_row11_col3, #T_e188d_row11_col4, #T_e188d_row11_col5, #T_e188d_row11_col6, #T_e188d_row12_col0, #T_e188d_row12_col1, #T_e188d_row12_col2, #T_e188d_row12_col3, #T_e188d_row12_col4, #T_e188d_row12_col5, #T_e188d_row12_col6, #T_e188d_row13_col0, #T_e188d_row13_col1, #T_e188d_row13_col2, #T_e188d_row13_col3, #T_e188d_row13_col4, #T_e188d_row13_col5, #T_e188d_row13_col6, #T_e188d_row14_col0, #T_e188d_row14_col1, #T_e188d_row14_col2, #T_e188d_row14_col3, #T_e188d_row14_col4, #T_e188d_row14_col5, #T_e188d_row14_col6, #T_e188d_row15_col0, #T_e188d_row15_col1, #T_e188d_row15_col2, #T_e188d_row15_col3, #T_e188d_row15_col4, #T_e188d_row15_col5, #T_e188d_row15_col6, #T_e188d_row16_col0, #T_e188d_row16_col1, #T_e188d_row16_col2, #T_e188d_row16_col3, #T_e188d_row16_col4, #T_e188d_row16_col5, #T_e188d_row16_col6, #T_e188d_row17_col0, #T_e188d_row17_col1, #T_e188d_row17_col2, #T_e188d_row17_col3, #T_e188d_row17_col4, #T_e188d_row17_col5, #T_e188d_row17_col6 {
#   text-align: left;
# }
# #T_e188d_row0_col1, #T_e188d_row0_col2, #T_e188d_row0_col3, #T_e188d_row0_col4, #T_e188d_row0_col5, #T_e188d_row0_col6, #T_e188d_row2_col6, #T_e188d_row3_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_e188d_row0_col7, #T_e188d_row1_col7, #T_e188d_row2_col7, #T_e188d_row3_col7, #T_e188d_row4_col7, #T_e188d_row5_col7, #T_e188d_row6_col7, #T_e188d_row7_col7, #T_e188d_row8_col7, #T_e188d_row9_col7, #T_e188d_row10_col7, #T_e188d_row11_col7, #T_e188d_row12_col7, #T_e188d_row13_col7, #T_e188d_row14_col7, #T_e188d_row15_col7, #T_e188d_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_e188d_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_e188d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e188d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e188d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e188d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e188d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e188d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e188d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e188d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_e188d_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e188d_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_e188d_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_e188d_row0_col1" class="data row0 col1" >0.1163</td>
#       <td id="T_e188d_row0_col2" class="data row0 col2" >0.0596</td>
#       <td id="T_e188d_row0_col3" class="data row0 col3" >0.2433</td>
#       <td id="T_e188d_row0_col4" class="data row0 col4" >0.9759</td>
#       <td id="T_e188d_row0_col5" class="data row0 col5" >0.0330</td>
#       <td id="T_e188d_row0_col6" class="data row0 col6" >0.0174</td>
#       <td id="T_e188d_row0_col7" class="data row0 col7" >0.7590</td>
#     </tr>
#     <tr>
#       <th id="T_e188d_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_e188d_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_e188d_row1_col1" class="data row1 col1" >0.1169</td>
#       <td id="T_e188d_row1_col2" class="data row1 col2" >0.0610</td>
#       <td id="T_e188d_row1_col3" class="data row1 col3" >0.2462</td>
#       <td id="T_e188d_row1_col4" class="data row1 col4" >0.9753</td>
#       <td id="T_e188d_row1_col5" class="data row1 col5" >0.0336</td>
#       <td id="T_e188d_row1_col6" class="data row1 col6" >0.0175</td>
#       <td id="T_e188d_row1_col7" class="data row1 col7" >0.2720</td>
#     </tr>
#     <tr>
#       <th id="T_e188d_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_e188d_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_e188d_row2_col1" class="data row2 col1" >0.1167</td>
#       <td id="T_e188d_row2_col2" class="data row2 col2" >0.0616</td>
#       <td id="T_e188d_row2_col3" class="data row2 col3" >0.2474</td>
#       <td id="T_e188d_row2_col4" class="data row2 col4" >0.9751</td>
#       <td id="T_e188d_row2_col5" class="data row2 col5" >0.0337</td>
#       <td id="T_e188d_row2_col6" class="data row2 col6" >0.0174</td>
#       <td id="T_e188d_row2_col7" class="data row2 col7" >0.1680</td>
#     </tr>
#     <tr>
#       <th id="T_e188d_level0_row3" class="row_heading level0 row3" >dt</th>
#       <td id="T_e188d_row3_col0" class="data row3 col0" >Decision Tree Regressor</td>
#       <td id="T_e188d_row3_col1" class="data row3 col1" >0.1168</td>
#       <td id="T_e188d_row3_col2" class="data row3 col2" >0.0622</td>
#       <td id="T_e188d_row3_col3" class="data row3 col3" >0.2485</td>
#       <td id="T_e188d_row3_col4" class="data row3 col4" >0.9748</td>
#       <td id="T_e188d_row3_col5" class="data row3 col5" >0.0338</td>
#       <td id="T_e188d_row3_col6" class="data row3 col6" >0.0174</td>
#       <td id="T_e188d_row3_col7" class="data row3 col7" >0.0260</td>
#     </tr>
#     <tr>
#       <th id="T_e188d_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_e188d_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_e188d_row4_col1" class="data row4 col1" >0.1199</td>
#       <td id="T_e188d_row4_col2" class="data row4 col2" >0.0679</td>
#       <td id="T_e188d_row4_col3" class="data row4 col3" >0.2598</td>
#       <td id="T_e188d_row4_col4" class="data row4 col4" >0.9725</td>
#       <td id="T_e188d_row4_col5" class="data row4 col5" >0.0363</td>
#       <td id="T_e188d_row4_col6" class="data row4 col6" >0.0182</td>
#       <td id="T_e188d_row4_col7" class="data row4 col7" >1.1710</td>
#     </tr>
#     <tr>
#       <th id="T_e188d_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_e188d_row5_col0" class="data row5 col0" >K Neighbors Regressor</td>
#       <td id="T_e188d_row5_col1" class="data row5 col1" >0.1202</td>
#       <td id="T_e188d_row5_col2" class="data row5 col2" >0.0717</td>
#       <td id="T_e188d_row5_col3" class="data row5 col3" >0.2667</td>
#       <td id="T_e188d_row5_col4" class="data row5 col4" >0.9710</td>
#       <td id="T_e188d_row5_col5" class="data row5 col5" >0.0367</td>
#       <td id="T_e188d_row5_col6" class="data row5 col6" >0.0179</td>
#       <td id="T_e188d_row5_col7" class="data row5 col7" >0.0490</td>
#     </tr>
#     <tr>
#       <th id="T_e188d_level

# %%
# functional API
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
plot_model(best, plot = 'residuals')

# %%
plot_model(best, plot = 'feature')

# %%
predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_284a2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_284a2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_284a2_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_284a2_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_284a2_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_284a2_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_284a2_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_284a2_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_284a2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_284a2_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_284a2_row0_col1" class="data row0 col1" >0.1154</td>
#       <td id="T_284a2_row0_col2" class="data row0 col2" >0.0549</td>
#       <td id="T_284a2_row0_col3" class="data row0 col3" >0.2344</td>
#       <td id="T_284a2_row0_col4" class="data row0 col4" >0.9782</td>
#       <td id="T_284a2_row0_col5" class="data row0 col5" >0.0310</td>
#       <td id="T_284a2_row0_col6" class="data row0 col6" >0.0171</td>
#     </tr>
#   </tbody>
# </table>
#        depth  ground_truth  prediction_label
# 9118   6.794           6.0          6.037968
# 21308  3.104           3.0          3.001840
# 8716   6.953           6.0          6.334492
# 15294  4.681           4.5          4.500216
# 5504   8.373           7.0          7.373901
# ...      ...           ...               ...
# 2531   8.940           7.5          7.686198
# 9588   6.161           6.0          5.578828
# 18585  3.670           3.5          3.510715
# 14768  4.893           4.5          4.519935
# 3936   8.433           7.5          7.452752
#
# [6649 rows x 3 columns]

# %%
predictions = predict_model(best, data=data)
# Out:
# <style type="text/css">
# </style>
# <table id="T_899e7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_899e7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_899e7_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_899e7_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_899e7_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_899e7_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_899e7_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_899e7_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_899e7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_899e7_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_899e7_row0_col1" class="data row0 col1" >0.1149</td>
#       <td id="T_899e7_row0_col2" class="data row0 col2" >0.0558</td>
#       <td id="T_899e7_row0_col3" class="data row0 col3" >0.2362</td>
#       <td id="T_899e7_row0_col4" class="data row0 col4" >0.9776</td>
#       <td id="T_899e7_row0_col5" class="data row0 col5" >0.0315</td>
#       <td id="T_899e7_row0_col6" class="data row0 col6" >0.0171</td>
#     </tr>
#   </tbody>
# </table>

# %%
predictions.head(500)
# Out:
#       depth  ground_truth  prediction_label
# 0     9.362           8.0          7.770806
# 1     8.743           8.0          7.604238
# 2     9.746           8.0          7.820908
# 3     8.743           8.0          7.604238
# 4     9.217           8.0          7.752450
# ..      ...           ...               ...
# 495   8.679           8.0          7.604238
# 496   9.746           8.0          7.820908
# 497   8.616           8.0          7.562633
# 498  10.430           8.0          7.937563
# 499  10.339           8.0          7.908724
#
# [500 rows x 3 columns]

# %%
predictions.to_csv('predictions.csv', index=False)

# %%
resuurces = pd.read_csv('predictions.csv')
resuurces
# Out:
#        depth  ground_truth  prediction_label
# 0      9.362           8.0          7.770806
# 1      8.743           8.0          7.604238
# 2      9.746           8.0          7.820908
# 3      8.743           8.0          7.604238
# 4      9.217           8.0          7.752450
# ...      ...           ...               ...
# 22155  3.121           3.0          3.001840
# 22156  3.080           3.0          3.001840
# 22157  3.162           3.0          3.001840
# 22158  3.041           3.0          3.001840
# 22159  3.025           3.0          3.001840
#
# [22160 rows x 3 columns]
