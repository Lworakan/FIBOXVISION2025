# %%
import pandas as pd

df = pd.read_csv('../data904/merged_detections.csv')
df
# Out:
#                    Timestamp  Frame  X_min  Y_min  X_max  Y_max  Confidence  \
# 0    2025-04-08 16:18:00.799      2    240      0    441    119        0.97
# 1    2025-04-08 16:18:01.594      3    241      0    441    119        0.97
# 2    2025-04-08 16:18:02.289      4    241      0    441    119        0.97
# 3    2025-04-08 16:18:02.901      5    240      0    442    120        0.97
# 4    2025-04-08 16:18:03.559      6    241      0    441    119        0.97
# ..                       ...    ...    ...    ...    ...    ...         ...
# 150  2025-04-08 16:13:26.597     12    279    120    371    184        0.96
# 151  2025-04-08 16:13:27.369     13    279    120    371    184        0.96
# 152  2025-04-08 16:13:28.355     14    279    120    371    184        0.96
# 153  2025-04-08 16:13:29.283     15    279    120    371    184        0.96
# 154  2025-04-08 16:13:30.130     16    279    120    371    184        0.96
#
#      Average_Depth_m   area  ground_truth               source_file
# 0              3.924  23919           3.5  realsense_detections3500
# 1              3.931  23800           3.5  realsense_detections3500
# 2              3.921  23800           3.5  realsense_detections3500
# 3              3.922  24240           3.5  realsense_detections3500
# 4              3.946  23800           3.5  realsense_detections3500
# ..               ...    ...           ...                       ...
# 150           10.757   5888           7.5  realsense_detections7500
# 151           10.394   5888           7.5  realsense_detections7500
# 152           10.519   5888           7.5  realsense_detections7500
# 153           10.623   5888           7.5  realsense_detections7500
# 154           10.579   5888           7.5  realsense_detections7500
#
# [155 rows x 11 columns]

# %%
# new dataframe get only depth and accealdatax and ground_truth

# Timestamp	Frame	X_min	Y_min	X_max	Y_max	Confidence	Average_Depth_m	area	ground_truth	
data = df[['X_min', 'Y_min', 'X_max', 'Y_max', 'Confidence', 'Average_Depth_m', 'area', 'ground_truth']]
data
# Out:
#      X_min  Y_min  X_max  Y_max  Confidence  Average_Depth_m   area  \
# 0      240      0    441    119        0.97            3.924  23919
# 1      241      0    441    119        0.97            3.931  23800
# 2      241      0    441    119        0.97            3.921  23800
# 3      240      0    442    120        0.97            3.922  24240
# 4      241      0    441    119        0.97            3.946  23800
# ..     ...    ...    ...    ...         ...              ...    ...
# 150    279    120    371    184        0.96           10.757   5888
# 151    279    120    371    184        0.96           10.394   5888
# 152    279    120    371    184        0.96           10.519   5888
# 153    279    120    371    184        0.96           10.623   5888
# 154    279    120    371    184        0.96           10.579   5888
#
#      ground_truth
# 0             3.5
# 1             3.5
# 2             3.5
# 3             3.5
# 4             3.5
# ..            ...
# 150           7.5
# 151           7.5
# 152           7.5
# 153           7.5
# 154           7.5
#
# [155 rows x 8 columns]

# %%
from pycaret.regression import *
# s = setup(df, target = 'ground_truth', session_id = 123, use_gpu=True, polynomial_features=True,polynomial_degree=2)
s = setup(data, target = 'ground_truth', session_id = 123, use_gpu=True, polynomial_features=True)
# Out:
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# <style type="text/css">
# #T_21fe8_row8_col1, #T_21fe8_row12_col1, #T_21fe8_row17_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_21fe8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21fe8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_21fe8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21fe8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_21fe8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_21fe8_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_21fe8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_21fe8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_21fe8_row1_col1" class="data row1 col1" >ground_truth</td>
#     </tr>
#     <tr>
#       <th id="T_21fe8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_21fe8_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_21fe8_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_21fe8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_21fe8_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_21fe8_row3_col1" class="data row3 col1" >(155, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_21fe8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_21fe8_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_21fe8_row4_col1" class="data row4 col1" >(155, 36)</td>
#     </tr>
#     <tr>
#       <th id="T_21fe8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_21fe8_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_21fe8_row5_col1" class="data row5 col1" >(108, 36)</td>
#     </tr>
#     <tr>
#       <th id="T_21fe8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_21fe8_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_21fe8_row6_col1" class="data row6 col1" >(47, 36)</td>
#     </tr>
#     <tr>
#       <th id="T_21fe8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_21fe8_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_21fe8_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_21fe8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_21fe8_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_21fe8_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_21fe8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_21fe8_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_21fe8_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_21fe8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_21fe8_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_21fe8_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_21fe8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_21fe8_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_21fe8_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_21fe8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_21fe8_row12_col0" class="data row12 col0" >Polynomial features</td>
#       <td id="T_21fe8_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_21fe8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_21fe8_row13_col0" class="data row13 col0" >Polynomial degree</td>
#       <td id="T_21fe8_row13_col1" class="data row13 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_21fe8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_21fe8_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_21fe8_row14_col1" class="data row14 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_21fe8_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_21fe8_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_21fe8_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_21fe8_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_21fe8_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_21fe8_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_21fe8_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_21fe8_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_21fe8_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_21fe8_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_21fe8_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_21fe8_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_21fe8_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_21fe8_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_21fe8_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_21fe8_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_21fe8_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_21fe8_row20_col1" class="data row20 col1" >3026</td>
#     </tr>
#   </tbody>
# </table>
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_b9346 th {
#   text-align: left;
# }
# #T_b9346_row0_col0, #T_b9346_row0_col1, #T_b9346_row0_col3, #T_b9346_row0_col5, #T_b9346_row0_col6, #T_b9346_row1_col0, #T_b9346_row2_col0, #T_b9346_row2_col1, #T_b9346_row2_col2, #T_b9346_row2_col3, #T_b9346_row2_col4, #T_b9346_row2_col5, #T_b9346_row2_col6, #T_b9346_row3_col0, #T_b9346_row3_col1, #T_b9346_row3_col2, #T_b9346_row3_col3, #T_b9346_row3_col4, #T_b9346_row3_col5, #T_b9346_row3_col6, #T_b9346_row4_col0, #T_b9346_row4_col1, #T_b9346_row4_col2, #T_b9346_row4_col3, #T_b9346_row4_col4, #T_b9346_row4_col5, #T_b9346_row4_col6, #T_b9346_row5_col0, #T_b9346_row5_col1, #T_b9346_row5_col2, #T_b9346_row5_col3, #T_b9346_row5_col4, #T_b9346_row5_col5, #T_b9346_row5_col6, #T_b9346_row6_col0, #T_b9346_row6_col1, #T_b9346_row6_col2, #T_b9346_row6_col3, #T_b9346_row6_col4, #T_b9346_row6_col5, #T_b9346_row6_col6, #T_b9346_row7_col0, #T_b9346_row7_col1, #T_b9346_row7_col2, #T_b9346_row7_col3, #T_b9346_row7_col4, #T_b9346_row7_col5, #T_b9346_row7_col6, #T_b9346_row8_col0, #T_b9346_row8_col1, #T_b9346_row8_col2, #T_b9346_row8_col3, #T_b9346_row8_col4, #T_b9346_row8_col5, #T_b9346_row8_col6, #T_b9346_row9_col0, #T_b9346_row9_col1, #T_b9346_row9_col2, #T_b9346_row9_col3, #T_b9346_row9_col4, #T_b9346_row9_col5, #T_b9346_row9_col6, #T_b9346_row10_col0, #T_b9346_row10_col1, #T_b9346_row10_col2, #T_b9346_row10_col3, #T_b9346_row10_col4, #T_b9346_row10_col5, #T_b9346_row10_col6, #T_b9346_row11_col0, #T_b9346_row11_col1, #T_b9346_row11_col2, #T_b9346_row11_col3, #T_b9346_row11_col4, #T_b9346_row11_col5, #T_b9346_row11_col6, #T_b9346_row12_col0, #T_b9346_row12_col1, #T_b9346_row12_col2, #T_b9346_row12_col3, #T_b9346_row12_col4, #T_b9346_row12_col5, #T_b9346_row12_col6, #T_b9346_row13_col0, #T_b9346_row13_col1, #T_b9346_row13_col2, #T_b9346_row13_col3, #T_b9346_row13_col4, #T_b9346_row13_col5, #T_b9346_row13_col6, #T_b9346_row14_col0, #T_b9346_row14_col1, #T_b9346_row14_col2, #T_b9346_row14_col3, #T_b9346_row14_col4, #T_b9346_row14_col5, #T_b9346_row14_col6, #T_b9346_row15_col0, #T_b9346_row15_col1, #T_b9346_row15_col2, #T_b9346_row15_col3, #T_b9346_row15_col4, #T_b9346_row15_col5, #T_b9346_row15_col6, #T_b9346_row16_col0, #T_b9346_row16_col1, #T_b9346_row16_col2, #T_b9346_row16_col3, #T_b9346_row16_col4, #T_b9346_row16_col5, #T_b9346_row16_col6, #T_b9346_row17_col0, #T_b9346_row17_col1, #T_b9346_row17_col2, #T_b9346_row17_col3, #T_b9346_row17_col4, #T_b9346_row17_col5, #T_b9346_row17_col6 {
#   text-align: left;
# }
# #T_b9346_row0_col2, #T_b9346_row0_col4, #T_b9346_row1_col1, #T_b9346_row1_col2, #T_b9346_row1_col3, #T_b9346_row1_col4, #T_b9346_row1_col5, #T_b9346_row1_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_b9346_row0_col7, #T_b9346_row1_col7, #T_b9346_row2_col7, #T_b9346_row3_col7, #T_b9346_row4_col7, #T_b9346_row5_col7, #T_b9346_row6_col7, #T_b9346_row7_col7, #T_b9346_row8_col7, #T_b9346_row9_col7, #T_b9346_row10_col7, #T_b9346_row11_col7, #T_b9346_row12_col7, #T_b9346_row13_col7, #T_b9346_row15_col7, #T_b9346_row16_col7, #T_b9346_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_b9346_row14_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_b9346">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9346_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b9346_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_b9346_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_b9346_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_b9346_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_b9346_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_b9346_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_b9346_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9346_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_b9346_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_b9346_row0_col1" class="data row0 col1" >0.0100</td>
#       <td id="T_b9346_row0_col2" class="data row0 col2" >0.0004</td>
#       <td id="T_b9346_row0_col3" class="data row0 col3" >0.0176</td>
#       <td id="T_b9346_row0_col4" class="data row0 col4" >0.9997</td>
#       <td id="T_b9346_row0_col5" class="data row0 col5" >0.0032</td>
#       <td id="T_b9346_row0_col6" class="data row0 col6" >0.0021</td>
#       <td id="T_b9346_row0_col7" class="data row0 col7" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_b9346_level0_row1" class="row_heading level0 row1" >gbr</th>
#       <td id="T_b9346_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#       <td id="T_b9346_row1_col1" class="data row1 col1" >0.0029</td>
#       <td id="T_b9346_row1_col2" class="data row1 col2" >0.0004</td>
#       <td id="T_b9346_row1_col3" class="data row1 col3" >0.0089</td>
#       <td id="T_b9346_row1_col4" class="data row1 col4" >0.9997</td>
#       <td id="T_b9346_row1_col5" class="data row1 col5" >0.0011</td>
#       <td id="T_b9346_row1_col6" class="data row1 col6" >0.0004</td>
#       <td id="T_b9346_row1_col7" class="data row1 col7" >0.0650</td>
#     </tr>
#     <tr>
#       <th id="T_b9346_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_b9346_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_b9346_row2_col1" class="data row2 col1" >0.0052</td>
#       <td id="T_b9346_row2_col2" class="data row2 col2" >0.0008</td>
#       <td id="T_b9346_row2_col3" class="data row2 col3" >0.0139</td>
#       <td id="T_b9346_row2_col4" class="data row2 col4" >0.9992</td>
#       <td id="T_b9346_row2_col5" class="data row2 col5" >0.0018</td>
#       <td id="T_b9346_row2_col6" class="data row2 col6" >0.0008</td>
#       <td id="T_b9346_row2_col7" class="data row2 col7" >0.3070</td>
#     </tr>
#     <tr>
#       <th id="T_b9346_level0_row3" class="row_heading level0 row3" >llar</th>
#       <td id="T_b9346_row3_col0" class="data row3 col0" >Lasso Least Angle Regression</td>
#       <td id="T_b9346_row3_col1" class="data row3 col1" >0.0251</td>
#       <td id="T_b9346_row3_col2" class="data row3 col2" >0.0014</td>
#       <td id="T_b9346_row3_col3" class="data row3 col3" >0.0353</td>
#       <td id="T_b9346_row3_col4" class="data row3 col4" >0.9990</td>
#       <td id="T_b9346_row3_col5" class="data row3 col5" >0.0051</td>
#       <td id="T_b9346_row3_col6" class="data row3 col6" >0.0046</td>
#       <td id="T_b9346_row3_col7" class="data row3 col7" >0.0480</td>
#     </tr>
#     <tr>
#       <th id="T_b9346_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_b9346_row4_col0" class="data row4 col0" >Extra Trees Regressor</td>
#       <td id="T_b9346_row4_col1" class="data row4 col1" >0.0052</td>
#       <td id="T_b9346_row4_col2" class="data row4 col2" >0.0010</td>
#       <td id="T_b9346_row4_col3" class="data row4 col3" >0.0145</td>
#       <td id="T_b9346_row4_col4" class="data row4 col4" >0.9990</td>
#       <td id="T_b9346_row4_col5" class="data row4 col5" >0.0019</td>
#       <td id="T_b9346_row4_col6" class="data row4 col6" >0.0008</td>
#       <td id="T_b9346_row4_col7" class="data row4 col7" >0.2400</td>
#     </tr>
#     <tr>
#       <th id="T_b9346_level0_row5" class="row_heading level0 row5" >en</th>
#       <td id="T_b9346_row5_col0" class="data row5 col0" >Elastic Net</td>
#       <td id="T_b9346_row5_col1" class="data row5 col1" >0.0288</td>
#       <td id="T_b9346_row5_col2" class="data row5 col2" >0.0021</td>
#       <td id="T_b9346_row5_col3" class="data row5 col3" >0.0413</td>
#       <td id="T_b9346_row5_col4" class="data row5 col4" >0.9984</td>
#       <td id="T_b9346_row5_col5" class="data row5 col5" >0.0059</td>
#       <td id="T_b9346_row5_col6" class="data row5 col6" >0.0053</td>
#       <td id="T_b9346_row5_col7" class="data row5 col7" >0.0280</td>
#     </tr>
#     <tr>
#       <th id="T_b9346_level0_row6" class="row_headi

# %%
# functional API
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
plot_model(best, plot = 'residuals')

# %%
plot_model(best, plot = 'feature')

# %%
predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_fa560">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa560_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fa560_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_fa560_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_fa560_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_fa560_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_fa560_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_fa560_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa560_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa560_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_fa560_row0_col1" class="data row0 col1" >0.0207</td>
#       <td id="T_fa560_row0_col2" class="data row0 col2" >0.0057</td>
#       <td id="T_fa560_row0_col3" class="data row0 col3" >0.0753</td>
#       <td id="T_fa560_row0_col4" class="data row0 col4" >0.9973</td>
#       <td id="T_fa560_row0_col5" class="data row0 col5" >0.0092</td>
#       <td id="T_fa560_row0_col6" class="data row0 col6" >0.0034</td>
#     </tr>
#   </tbody>
# </table>
#      X_min  Y_min  X_max  Y_max  Confidence  Average_Depth_m   area  \
# 116    276    103    382    176        0.96            8.748   7738
# 81     253     59    392    160        0.97            6.037  14039
# 132    275    113    373    182        0.96           10.146   6762
# 24     209      0    409    120        0.97            3.992  24000
# 100    250     78    376    163        0.97            7.293  10710
# 95     250     78    376    163        0.97            7.259  10710
# 42     241     16    415    135        0.96            4.624  20706
# 41     240     15    414    136        0.97            4.665  21054
# 141    278    120    371    184        0.96           10.735   5952
# 74     253     59    392    160        0.97            6.268  14039
# 65     246     39    399    148        0.96            5.209  16677
# 8      241      0    441    119        0.97            3.942  23800
# 59     245     38    399    149        0.96            5.253  17094
# 146    278    120    371    184        0.96           10.631   5952
# 63     246     39    399    147        0.96            5.102  16524
# 107    258     91    374    172        0.96            8.054   9396
# 33     241     16    415    137        0.96            4.638  21054
# 128    272    115    371    183        0.96            9.730   6732
# 13     241      0    441    119        0.97            3.911  23800
# 93     250     78    376    163        0.97            7.325  10710
# 140    279    120    371    184        0.96           10.568   5888
# 31     209      0    409    120        0.97            4.008  24000
# 104    250     78    376    163        0.97            7.316  10710
# 130    275    114    374    183        0.96            9.726   6831
# 108    258     91    374    172        0.96            8.145   9396
# 53     241     16    415    137        0.96            4.674  21054
# 20     208      0    408    120        0.97            4.068  24000
# 37     241     15    415    136        0.96            4.622  21054
# 28     209      0    409    120        0.97            4.066  24000
# 88     250     78    376    163        0.97            7.193  10710
# 36     242     16    415    140        0.96            4.675  21452
# 147    279    120    371    184        0.96           10.505   5888
# 125    279    120    371    184        0.96           10.655   5888
# 4      241      0    441    119        0.97            3.946  23800
# 138    275    114    373    183        0.96            9.711   6762
# 45     240     15    415    136        0.97            4.520  21175
# 29     209      0    408    120        0.97            4.011  23880
# 87     250     78    376    163        0.97            7.159  10710
# 0      240      0    441    119        0.97            3.924  23919
# 82     253     59    392    160        0.97            6.174  14039
# 151    279    120    371    184        0.96           10.394   5888
# 101    250     78    376    163        0.97            7.235  10710
# 110    258     91    374    172        0.96            8.093   9396
# 5      241      0    441    119        0.97            3.921  23800
# 16     228      0    428    120        0.97            4.067  24000
# 139    275    114    373    183        0.96            9.720   6762
# 127    270    116    367    183        0.96            8.951   6499
#
#      ground_truth  prediction_label
# 116           6.5          6.488577
# 81            5.0          4.999131
# 132           7.0          7.004670
# 24            3.5          3.497437
# 100           5.5          5.500483
# 95            5.5          5.500298
# 42            4.0          4.012161
# 41            4.0          4.014577
# 141           7.5          7.454622
# 74            5.0          4.999928
# 65            4.5          4.504527
# 8             3.5          3.493831
# 59            4.5          4.478689
# 146           7.5          7.453485
# 63            4.5          4.498362
# 107           6.0          5.999905
# 33            4.0          4.011719
# 128           7.0          7.046663
# 13            3.5          3.505505
# 93            5.5          5.500620
# 140           7.5          7.500215
# 31            3.5          3.498291
# 104           5.5          5.500585
# 130           7.0          6.984028
# 108           6.0          6.010300
# 53            4.0          4.013285
# 20            3.5          3.497253
# 37            4.0          3.995252
# 28            3.5          3.501309
# 88            5.5          5.499823
# 36            4.0          4.016233
# 147           7.5          7.499358
# 125           7.0          7.501169
# 4             3.5          3.492323
# 138           7.0          7.015819
# 45            4.0          3.983024
# 29            3.5          3.503272
# 87            5.5          5.499519
# 0             3.5          3.513344
# 82            5.0          4.999830
# 151           7.5          7.497508
# 101           5.5          5.500143
# 110           6.0          6.004396
# 5             3.5          3.501743
# 16            3.5          3.509633
# 139           7.0          7.016252
# 127           7.0          7.073456

# %%
predictions = predict_model(best, data=data)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a829c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a829c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a829c_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a829c_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a829c_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a829c_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a829c_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a829c_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a829c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a829c_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_a829c_row0_col1" class="data row0 col1" >0.0091</td>
#       <td id="T_a829c_row0_col2" class="data row0 col2" >0.0017</td>
#       <td id="T_a829c_row0_col3" class="data row0 col3" >0.0418</td>
#       <td id="T_a829c_row0_col4" class="data row0 col4" >0.9991</td>
#       <td id="T_a829c_row0_col5" class="data row0 col5" >0.0051</td>
#       <td id="T_a829c_row0_col6" class="data row0 col6" >0.0016</td>
#     </tr>
#   </tbody>
# </table>

# %%
predictions.head(500)
# Out:
#      X_min  Y_min  X_max  Y_max  Confidence  Average_Depth_m   area  \
# 0      240      0    441    119        0.97            3.924  23919
# 1      241      0    441    119        0.97            3.931  23800
# 2      241      0    441    119        0.97            3.921  23800
# 3      240      0    442    120        0.97            3.922  24240
# 4      241      0    441    119        0.97            3.946  23800
# ..     ...    ...    ...    ...         ...              ...    ...
# 150    279    120    371    184        0.96           10.757   5888
# 151    279    120    371    184        0.96           10.394   5888
# 152    279    120    371    184        0.96           10.519   5888
# 153    279    120    371    184        0.96           10.623   5888
# 154    279    120    371    184        0.96           10.579   5888
#
#      ground_truth  prediction_label
# 0             3.5          3.513344
# 1             3.5          3.497977
# 2             3.5          3.501743
# 3             3.5          3.500742
# 4             3.5          3.492323
# ..            ...               ...
# 150           7.5          7.501948
# 151           7.5          7.497508
# 152           7.5          7.499560
# 153           7.5          7.500849
# 154           7.5          7.500350
#
# [155 rows x 9 columns]

# %%
predictions.to_csv('predictions.csv', index=False)

# %%
resuurces = pd.read_csv('predictions.csv')
resuurces
# Out:
#      X_min  Y_min  X_max  Y_max  Confidence  Average_Depth_m   area  \
# 0      240      0    441    119        0.97            3.924  23919
# 1      241      0    441    119        0.97            3.931  23800
# 2      241      0    441    119        0.97            3.921  23800
# 3      240      0    442    120        0.97            3.922  24240
# 4      241      0    441    119        0.97            3.946  23800
# ..     ...    ...    ...    ...         ...              ...    ...
# 150    279    120    371    184        0.96           10.757   5888
# 151    279    120    371    184        0.96           10.394   5888
# 152    279    120    371    184        0.96           10.519   5888
# 153    279    120    371    184        0.96           10.623   5888
# 154    279    120    371    184        0.96           10.579   5888
#
#      ground_truth  prediction_label
# 0             3.5          3.513344
# 1             3.5          3.497977
# 2             3.5          3.501743
# 3             3.5          3.500742
# 4             3.5          3.492323
# ..            ...               ...
# 150           7.5          7.501948
# 151           7.5          7.497508
# 152           7.5          7.499560
# 153           7.5          7.500849
# 154           7.5          7.500350
#
# [155 rows x 9 columns]

# %%
finalized_model = finalize_model(best)
save_model(finalized_model, 'final_calibrated_depth_model_outdoor_v2_linear')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['X_min', 'Y_min', 'X_max', 'Y_max',
#                                               'Confidence', 'Average_Depth_m',
#                                               'area'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('polynomial_features',
#                   TransformerWrapper(transformer=PolynomialFeatures(include_bias=False))),
#                  ('actual_estimator', LinearRegression(n_jobs=-1))]),
#  'final_calibrated_depth_model_outdoor_v2_linear.pkl')

# %%
best_calib_loc_model = compare_models(sort='RMSE')
tuned_best_model = tune_model(best_calib_loc_model, optimize='RMSE', n_iter=50)
base_model_for_comparison = tuned_best_model
final_model = base_model_for_comparison
finalized_model = finalize_model(final_model)
save_model(finalized_model, 'final_calibrated_depth_model_outdoor_v2')
# Out:
# <style type="text/css">
# #T_99bb5 th {
#   text-align: left;
# }
# #T_99bb5_row0_col0, #T_99bb5_row1_col0, #T_99bb5_row1_col1, #T_99bb5_row1_col2, #T_99bb5_row1_col3, #T_99bb5_row1_col4, #T_99bb5_row1_col5, #T_99bb5_row1_col6, #T_99bb5_row2_col0, #T_99bb5_row2_col1, #T_99bb5_row2_col2, #T_99bb5_row2_col3, #T_99bb5_row2_col4, #T_99bb5_row2_col5, #T_99bb5_row2_col6, #T_99bb5_row3_col0, #T_99bb5_row3_col1, #T_99bb5_row3_col2, #T_99bb5_row3_col3, #T_99bb5_row3_col4, #T_99bb5_row3_col5, #T_99bb5_row3_col6, #T_99bb5_row4_col0, #T_99bb5_row4_col1, #T_99bb5_row4_col3, #T_99bb5_row4_col5, #T_99bb5_row4_col6, #T_99bb5_row5_col0, #T_99bb5_row5_col1, #T_99bb5_row5_col2, #T_99bb5_row5_col3, #T_99bb5_row5_col4, #T_99bb5_row5_col5, #T_99bb5_row5_col6, #T_99bb5_row6_col0, #T_99bb5_row6_col1, #T_99bb5_row6_col2, #T_99bb5_row6_col3, #T_99bb5_row6_col4, #T_99bb5_row6_col5, #T_99bb5_row6_col6, #T_99bb5_row7_col0, #T_99bb5_row7_col1, #T_99bb5_row7_col2, #T_99bb5_row7_col3, #T_99bb5_row7_col4, #T_99bb5_row7_col5, #T_99bb5_row7_col6, #T_99bb5_row8_col0, #T_99bb5_row8_col1, #T_99bb5_row8_col2, #T_99bb5_row8_col3, #T_99bb5_row8_col4, #T_99bb5_row8_col5, #T_99bb5_row8_col6, #T_99bb5_row9_col0, #T_99bb5_row9_col1, #T_99bb5_row9_col2, #T_99bb5_row9_col3, #T_99bb5_row9_col4, #T_99bb5_row9_col5, #T_99bb5_row9_col6, #T_99bb5_row10_col0, #T_99bb5_row10_col1, #T_99bb5_row10_col2, #T_99bb5_row10_col3, #T_99bb5_row10_col4, #T_99bb5_row10_col5, #T_99bb5_row10_col6, #T_99bb5_row11_col0, #T_99bb5_row11_col1, #T_99bb5_row11_col2, #T_99bb5_row11_col3, #T_99bb5_row11_col4, #T_99bb5_row11_col5, #T_99bb5_row11_col6, #T_99bb5_row12_col0, #T_99bb5_row12_col1, #T_99bb5_row12_col2, #T_99bb5_row12_col3, #T_99bb5_row12_col4, #T_99bb5_row12_col5, #T_99bb5_row12_col6, #T_99bb5_row13_col0, #T_99bb5_row13_col1, #T_99bb5_row13_col2, #T_99bb5_row13_col3, #T_99bb5_row13_col4, #T_99bb5_row13_col5, #T_99bb5_row13_col6, #T_99bb5_row14_col0, #T_99bb5_row14_col1, #T_99bb5_row14_col2, #T_99bb5_row14_col3, #T_99bb5_row14_col4, #T_99bb5_row14_col5, #T_99bb5_row14_col6, #T_99bb5_row15_col0, #T_99bb5_row15_col1, #T_99bb5_row15_col2, #T_99bb5_row15_col3, #T_99bb5_row15_col4, #T_99bb5_row15_col5, #T_99bb5_row15_col6, #T_99bb5_row16_col0, #T_99bb5_row16_col1, #T_99bb5_row16_col2, #T_99bb5_row16_col3, #T_99bb5_row16_col4, #T_99bb5_row16_col5, #T_99bb5_row16_col6, #T_99bb5_row17_col0, #T_99bb5_row17_col1, #T_99bb5_row17_col2, #T_99bb5_row17_col3, #T_99bb5_row17_col4, #T_99bb5_row17_col5, #T_99bb5_row17_col6 {
#   text-align: left;
# }
# #T_99bb5_row0_col1, #T_99bb5_row0_col2, #T_99bb5_row0_col3, #T_99bb5_row0_col4, #T_99bb5_row0_col5, #T_99bb5_row0_col6, #T_99bb5_row4_col2, #T_99bb5_row4_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_99bb5_row0_col7, #T_99bb5_row1_col7, #T_99bb5_row2_col7, #T_99bb5_row3_col7, #T_99bb5_row4_col7, #T_99bb5_row5_col7, #T_99bb5_row7_col7, #T_99bb5_row8_col7, #T_99bb5_row9_col7, #T_99bb5_row10_col7, #T_99bb5_row11_col7, #T_99bb5_row12_col7, #T_99bb5_row13_col7, #T_99bb5_row14_col7, #T_99bb5_row15_col7, #T_99bb5_row16_col7, #T_99bb5_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_99bb5_row6_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_99bb5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99bb5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_99bb5_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_99bb5_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_99bb5_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_99bb5_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_99bb5_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_99bb5_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_99bb5_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99bb5_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_99bb5_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_99bb5_row0_col1" class="data row0 col1" >0.0029</td>
#       <td id="T_99bb5_row0_col2" class="data row0 col2" >0.0004</td>
#       <td id="T_99bb5_row0_col3" class="data row0 col3" >0.0089</td>
#       <td id="T_99bb5_row0_col4" class="data row0 col4" >0.9997</td>
#       <td id="T_99bb5_row0_col5" class="data row0 col5" >0.0011</td>
#       <td id="T_99bb5_row0_col6" class="data row0 col6" >0.0004</td>
#       <td id="T_99bb5_row0_col7" class="data row0 col7" >0.0920</td>
#     </tr>
#     <tr>
#       <th id="T_99bb5_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_99bb5_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_99bb5_row1_col1" class="data row1 col1" >0.0052</td>
#       <td id="T_99bb5_row1_col2" class="data row1 col2" >0.0008</td>
#       <td id="T_99bb5_row1_col3" class="data row1 col3" >0.0139</td>
#       <td id="T_99bb5_row1_col4" class="data row1 col4" >0.9992</td>
#       <td id="T_99bb5_row1_col5" class="data row1 col5" >0.0018</td>
#       <td id="T_99bb5_row1_col6" class="data row1 col6" >0.0008</td>
#       <td id="T_99bb5_row1_col7" class="data row1 col7" >0.3350</td>
#     </tr>
#     <tr>
#       <th id="T_99bb5_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_99bb5_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_99bb5_row2_col1" class="data row2 col1" >0.0052</td>
#       <td id="T_99bb5_row2_col2" class="data row2 col2" >0.0010</td>
#       <td id="T_99bb5_row2_col3" class="data row2 col3" >0.0145</td>
#       <td id="T_99bb5_row2_col4" class="data row2 col4" >0.9990</td>
#       <td id="T_99bb5_row2_col5" class="data row2 col5" >0.0019</td>
#       <td id="T_99bb5_row2_col6" class="data row2 col6" >0.0008</td>
#       <td id="T_99bb5_row2_col7" class="data row2 col7" >0.2280</td>
#     </tr>
#     <tr>
#       <th id="T_99bb5_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_99bb5_row3_col0" class="data row3 col0" >AdaBoost Regressor</td>
#       <td id="T_99bb5_row3_col1" class="data row3 col1" >0.0050</td>
#       <td id="T_99bb5_row3_col2" class="data row3 col2" >0.0025</td>
#       <td id="T_99bb5_row3_col3" class="data row3 col3" >0.0158</td>
#       <td id="T_99bb5_row3_col4" class="data row3 col4" >0.9975</td>
#       <td id="T_99bb5_row3_col5" class="data row3 col5" >0.0019</td>
#       <td id="T_99bb5_row3_col6" class="data row3 col6" >0.0007</td>
#       <td id="T_99bb5_row3_col7" class="data row3 col7" >0.0730</td>
#     </tr>
#     <tr>
#       <th id="T_99bb5_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_99bb5_row4_col0" class="data row4 col0" >Linear Regression</td>
#       <td id="T_99bb5_row4_col1" class="data row4 col1" >0.0100</td>
#       <td id="T_99bb5_row4_col2" class="data row4 col2" >0.0004</td>
#       <td id="T_99bb5_row4_col3" class="data row4 col3" >0.0176</td>
#       <td id="T_99bb5_row4_col4" class="data row4 col4" >0.9997</td>
#       <td id="T_99bb5_row4_col5" class="data row4 col5" >0.0032</td>
#       <td id="T_99bb5_row4_col6" class="data row4 col6" >0.0021</td>
#       <td id="T_99bb5_row4_col7" class="data row4 col7" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_99bb5_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_99bb5_row5_col0" class="data row5 col0" >K Neighbors Regressor</td>
#       <td id="T_99bb5_row5_col1" class="data row5 col1" >0.0090</td>
#       <td id="T_99bb5_row5_col2" class="data row5 col2" >0.0029</td>
#       <td id="T_99bb5_row5_col3" class="data row5 col3" >0.0209</td>
#       <td id="T_99bb5_row5_col4" class="data row5 col4" >0.9972</td>
#       <td id="T_99bb5_row5_col5" class="data row5 col5" >0.0027</td>
#       <td id="T_99bb5_row5_col6" class="data row5 col6" >0.0014</td>
#       <td id="T_99bb5_row5_col7" class="data row5 col7" >0.0130</td>
#     </tr>
#     <tr>
#       <th id="T_99bb5_level0_row6" class="row_headi
# <style type="text/css">
# #T_06c6b_row10_col0, #T_06c6b_row10_col1, #T_06c6b_row10_col2, #T_06c6b_row10_col3, #T_06c6b_row10_col4, #T_06c6b_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_06c6b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06c6b_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_06c6b_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_06c6b_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_06c6b_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_06c6b_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_06c6b_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06c6b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_06c6b_row0_col0" class="data row0 col0" >0.0072</td>
#       <td id="T_06c6b_row0_col1" class="data row0 col1" >0.0003</td>
#       <td id="T_06c6b_row0_col2" class="data row0 col2" >0.0168</td>
#       <td id="T_06c6b_row0_col3" class="data row0 col3" >0.9998</td>
#       <td id="T_06c6b_row0_col4" class="data row0 col4" >0.0020</td>
#       <td id="T_06c6b_row0_col5" class="data row0 col5" >0.0012</td>
#     </tr>
#     <tr>
#       <th id="T_06c6b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_06c6b_row1_col0" class="data row1 col0" >0.0095</td>
#       <td id="T_06c6b_row1_col1" class="data row1 col1" >0.0003</td>
#       <td id="T_06c6b_row1_col2" class="data row1 col2" >0.0168</td>
#       <td id="T_06c6b_row1_col3" class="data row1 col3" >0.9999</td>
#       <td id="T_06c6b_row1_col4" class="data row1 col4" >0.0023</td>
#       <td id="T_06c6b_row1_col5" class="data row1 col5" >0.0019</td>
#     </tr>
#     <tr>
#       <th id="T_06c6b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_06c6b_row2_col0" class="data row2 col0" >0.0046</td>
#       <td id="T_06c6b_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_06c6b_row2_col2" class="data row2 col2" >0.0065</td>
#       <td id="T_06c6b_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_06c6b_row2_col4" class="data row2 col4" >0.0009</td>
#       <td id="T_06c6b_row2_col5" class="data row2 col5" >0.0008</td>
#     </tr>
#     <tr>
#       <th id="T_06c6b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_06c6b_row3_col0" class="data row3 col0" >0.0041</td>
#       <td id="T_06c6b_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_06c6b_row3_col2" class="data row3 col2" >0.0054</td>
#       <td id="T_06c6b_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_06c6b_row3_col4" class="data row3 col4" >0.0011</td>
#       <td id="T_06c6b_row3_col5" class="data row3 col5" >0.0010</td>
#     </tr>
#     <tr>
#       <th id="T_06c6b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_06c6b_row4_col0" class="data row4 col0" >0.0058</td>
#       <td id="T_06c6b_row4_col1" class="data row4 col1" >0.0001</td>
#       <td id="T_06c6b_row4_col2" class="data row4 col2" >0.0073</td>
#       <td id="T_06c6b_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_06c6b_row4_col4" class="data row4 col4" >0.0016</td>
#       <td id="T_06c6b_row4_col5" class="data row4 col5" >0.0016</td>
#     </tr>
#     <tr>
#       <th id="T_06c6b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_06c6b_row5_col0" class="data row5 col0" >0.0047</td>
#       <td id="T_06c6b_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_06c6b_row5_col2" class="data row5 col2" >0.0071</td>
#       <td id="T_06c6b_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_06c6b_row5_col4" class="data row5 col4" >0.0011</td>
#       <td id="T_06c6b_row5_col5" class="data row5 col5" >0.0009</td>
#     </tr>
#     <tr>
#       <th id="T_06c6b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_06c6b_row6_col0" class="data row6 col0" >0.0027</td>
#       <td id="T_06c6b_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_06c6b_row6_col2" class="data row6 col2" >0.0037</td>
#       <td id="T_06c6b_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_06c6b_row6_col4" class="data row6 col4" >0.0008</td>
#       <td id="T_06c6b_row6_col5" class="data row6 col5" >0.0007</td>
#     </tr>
#     <tr>
#       <th id="T_06c6b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_06c6b_row7_col0" class="data row7 col0" >0.0094</td>
#       <td id="T_06c6b_row7_col1" class="data row7 col1" >0.0003</td>
#       <td id="T_06c6b_row7_col2" class="data row7 col2" >0.0172</td>
#       <td id="T_06c6b_row7_col3" class="data row7 col3" >0.9999</td>
#       <td id="T_06c6b_row7_col4" class="data row7 col4" >0.0022</td>
#       <td id="T_06c6b_row7_col5" class="data row7 col5" >0.0015</td>
#     </tr>
#     <tr>
#       <th id="T_06c6b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_06c6b_row8_col0" class="data row8 col0" >0.0054</td>
#       <td id="T_06c6b_row8_col1" class="data row8 col1" >0.0001</td>
#       <td id="T_06c6b_row8_col2" class="data row8 col2" >0.0087</td>
#       <td id="T_06c6b_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_06c6b_row8_col4" class="data row8 col4" >0.0010</td>
#       <td id="T_06c6b_row8_col5" class="data row8 col5" >0.0008</td>
#     </tr>
#     <tr>
#       <th id="T_06c6b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_06c6b_row9_col0" class="data row9 col0" >0.0326</td>
#       <td id="T_06c6b_row9_col1" class="data row9 col1" >0.0094</td>
#       <td id="T_06c6b_row9_col2" class="data row9 col2" >0.0971</td>
#       <td id="T_06c6b_row9_col3" class="data row9 col3" >0.9905</td>
#       <td id="T_06c6b_row9_col4" class="data row9 col4" >0.0119</td>
#       <td id="T_06c6b_row9_col5" class="data row9 col5" >0.0048</td>
#     </tr>
#     <tr>
#       <th id="T_06c6b_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_06c6b_row10_col0" class="data row10 col0" >0.0086</td>
#       <td id="T_06c6b_row10_col1" class="data row10 col1" >0.0011</td>
#       <td id="T_06c6b_row10_col2" class="data row10 col2" >0.0187</td>
#       <td id="T_06c6b_row10_col3" class="data row10 col3" >0.9990</td>
#       <td id="T_06c6b_row10_col4" class="data row10 col4" >0.0025</td>
#       <td id="T_06c6b_row10_col5" class="data row10 col5" >0.0015</td>
#     </tr>
#     <tr>
#       <th id="T_06c6b_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_06c6b_row11_col0" class="data row11 col0" >0.0083</td>
#       <td id="T_06c6b_row11_col1" class="data row11 col1" >0.0028</td>
#       <td id="T_06c6b_row11_col2" class="data row11 col2" >0.0266</td>
#       <td id="T_06c6b_row11_col3" class="data row11 col3" >0.0028</td>
#       <td id="T_06c6b_row11_col4" class="data row11 col4" >0.0032</td>
#       <td id="T_06c6b_row11_col5" class="data row11 col5" >0.0012</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['X_min', 'Y_min', 'X_max', 'Y_max',
#                                               'Confidence', 'Average_Depth_m',
#                                               'area'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('polynomial_features',
#                   TransformerWrapper(transformer=PolynomialFeatures(include_bias=False))),
#                  ('actual_estimator',
#                   GradientBoostingRegressor(random_state=123))]),
#  'final_calibrated_depth_model_outdoor_v2.pkl')

# %%
loaded_bestmodel = load_model('final_calibrated_depth_model_outdoor_v2')
print(loaded_bestmodel)
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['X_min', 'Y_min', 'X_max', 'Y_max',
#                                              'Confidence', 'Average_Depth_m',
#                                              'area'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=[],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('polynomial_features',
#                  TransformerWrapper(transformer=PolynomialFeatures(include_bias=False))),
#                 ('actual_estimator',
#                  GradientBoostingRegressor(random_state=123))])

# %%
Example_data = pd.DataFrame({
    'Timestamp': [0],
    'Frame': [0],
    'X_min': [0],
    'Y_min': [0],
    'X_max': [0],
    'Y_max': [0],
    'Confidence': [0],
    'Average_Depth_m': [0],
    'area': [0]
})
predict_new = predict_model(best, data=Example_data)
predict_new.head()
# Out:
#    Timestamp  Frame  X_min  Y_min  X_max  Y_max  Confidence  Average_Depth_m  \
# 0          0      0      0      0      0      0           0                0
#
#    area  prediction_label
# 0     0       -779.643786
